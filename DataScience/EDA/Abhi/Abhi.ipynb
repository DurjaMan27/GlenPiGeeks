# %%
import pandas as pd
import matplotlib.pyplot as plt

#philcrime = pd.read_csv('/home/ec2-user/SageMaker/GlenPiGeeks/DataScience/Data/Abhi/crime.csv', header = 0, low_memory=False)
debt_df = pd.read_csv('/home/ec2-user/SageMaker/GlenPiGeeks/DataScience/Data/Abhi/debt_per_capita.csv', header = 0)
#pd.to_numeric(debt_df.columns[1:])
debt_df.dropna(inplace = True) 
debt_df.astype('float', errors='ignore').dtypes
#debt_df = debt_df.astype({"Q4_2003":'int64', "Q4_2003":'int64'}) 
debt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 52
# Data columns (total 17 columns):
# state      52 non-null object
# Q4_2003    52 non-null int64
# Q4_2004    52 non-null int64
# Q4_2005    52 non-null int64
# Q4_2006    52 non-null int64
# Q4_2007    52 non-null int64
# Q4_2008    52 non-null int64
# Q4_2009    52 non-null int64
# Q4_2010    52 non-null int64
# Q4_2011    52 non-null int64
# Q4_2012    52 non-null int64
# Q4_2013    52 non-null int64
# Q4_2014    52 non-null int64
# Q4_2015    52 non-null int64
# Q4_2016    52 non-null int64
# Q4_2017    52 non-null float64
# Q4_2018    52 non-null float64
# dtypes: float64(2), int64(14), object(1)
# memory usage: 7.3+ KB

# %%
plt.figure(figsize=(20,12))
plt.plot('state',  'Q4_2018', data=debt_df, markerfacecolor='green', markersize=12, color='skyblue', linewidth=4)
plt.plot('state',  'Q4_2017', data=debt_df, marker='X', color='olive', linewidth=2)
plt.plot('state',  'Q4_2016', data=debt_df, marker='^', color='red', linewidth=2, linestyle='dashed')
tyle='dashed'
plt.xticks(rotation=90)
plt.xlabel  = 'this is a xlabel \n  with newlines!'
plt.ylabel  = 'this is vertical\ntest'
plt.legend()
plt.show()
