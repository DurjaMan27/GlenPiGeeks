# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
nfl_df = pd.read_csv('/home/ec2-user/SageMaker/GlenPiGeeks/DataScience/Data/Varun/NFL_Data_Science_2018_2019.csv', header = 1)

# %%
nfl_df.head(10)
# Out:
#    Unnamed: 0 Year (Regular Season)                Team  Yards Gained  \
# 0         NaN                   NaN                 NaN           NaN
# 1         NaN             2018-2019   Arizona Cardinals         241.6
# 2         NaN             2018-2019     Atlanta Falcons         389.1
# 3         NaN             2018-2019    Baltimore Ravens         374.9
# 4         NaN             2018-2019       Buffalo Bills         298.6
# 5         NaN             2018-2019   Carolina Panthers         373.2
# 6         NaN             2018-2019       Chicago Bears         343.9
# 7         NaN             2018-2019  Cincinnati Bengals         310.8
# 8         NaN             2018-2019    Cleveland Browns         368.8
# 9         NaN             2018-2019      Dallas Cowboys         343.8
#
#    Yards Allowed  Turnover Ratio  Average Roster Age  Opposing Team Win %  \
# 0            NaN             NaN                 NaN                  NaN
# ...

# %%
nfl_df.drop([0], axis=0, inplace=True)

# %%
nfl_df.drop(nfl_df.columns[0], axis=1, inplace=True)

# %%
nfl_df.head(10)
# Out:
#    Year (Regular Season)                Team  Yards Gained  Yards Allowed  \
# 1              2018-2019   Arizona Cardinals         241.6          358.8
# 2              2018-2019     Atlanta Falcons         389.1          384.5
# 3              2018-2019    Baltimore Ravens         374.9          292.9
# 4              2018-2019       Buffalo Bills         298.6          294.1
# 5              2018-2019   Carolina Panthers         373.2          353.2
# 6              2018-2019       Chicago Bears         343.9          299.7
# 7              2018-2019  Cincinnati Bengals         310.8          413.6
# 8              2018-2019    Cleveland Browns         368.8          393.0
# 9              2018-2019      Dallas Cowboys         343.8          329.2
# 10             2018-2019      Denver Broncos         350.1          365.1
#
#     Turnover Ratio  Average Roster Age  Opposing Team Win %   PPG    PA
# 1            -12.0                26.5                  NaN  14.1  26.6
# ...

# %%
nfl_df.drop("Opposing Team Win %", axis=1, inplace=True)

# %%
nfl_df.head(10)
# Out:
#    Year (Regular Season)                Team  Yards Gained  Yards Allowed  \
# 1              2018-2019   Arizona Cardinals         241.6          358.8
# 2              2018-2019     Atlanta Falcons         389.1          384.5
# 3              2018-2019    Baltimore Ravens         374.9          292.9
# 4              2018-2019       Buffalo Bills         298.6          294.1
# 5              2018-2019   Carolina Panthers         373.2          353.2
# 6              2018-2019       Chicago Bears         343.9          299.7
# 7              2018-2019  Cincinnati Bengals         310.8          413.6
# 8              2018-2019    Cleveland Browns         368.8          393.0
# 9              2018-2019      Dallas Cowboys         343.8          329.2
# 10             2018-2019      Denver Broncos         350.1          365.1
#
#     Turnover Ratio  Average Roster Age   PPG    PA
# 1            -12.0                26.5  14.1  26.6
# 2              1.0                26.9  25.9  26.4
# ...

# %%
nfl_df.plot(kind='scatter',x='PPG',y='Yards Gained',color='blue')

# %%
nfl_df.plot(kind='scatter', x='PA', y='Yards Allowed', color='purple')
